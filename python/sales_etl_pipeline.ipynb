# %%
import pandas as pd

# %%
df = pd.read_excel("raw_sales_data.xlsx")

df.head()
# Out:
#   Order_ID  Order_Date Region     Sales_Rep Product_Category   Revenue  \
# 0  ORD0001  2024-12-22   West  James Wilson         Software   1754.20
# 1  ORD0002  2024-10-24   East   Linda Davis      Electronics  19834.97
# 2  ORD0003  2024-04-19   East    John Smith      Accessories  17139.86
# 3  ORD0004  2024-09-13  South  James Wilson        Furniture  16920.83
# 4  ORD0005  2024-08-29   East   David Brown      Electronics   5666.91
#
#    Discount    Target
# 0      0.13  20831.42
# 1      0.07   7502.10
# 2      0.08  11821.59
# 3      0.08  16017.80
# 4      0.10  19680.63

# %%
df = df.dropna()

# %%
df["Region"] = df["Region"].str.strip().str.title()

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df["Net_Revenue"] = df["Revenue"] - df["Discount"]

# %%
df["Month"] = df["Order_Date"].dt.month

# %%
df["Year"] = df["Order_Date"].dt.year

# %%
df["Margin_%"] = (df["Net_Revenue"] / df["Revenue"]) * 100

# %%
df.to_csv("cleaned_sales_data.csv", index=False)

# %%
display(df.head())
